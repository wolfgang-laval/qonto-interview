# %%
import sys
import os
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.ticker as mticker
import warnings

# %%
sys.path.append(os.path.abspath(".."))
ROOT_DIR = os.path.abspath("..")
DATA_FILE = os.path.join(ROOT_DIR, "data", "raw", "skills-test-ml-eng-data-products.csv")

# %%
df = pd.read_csv(DATA_FILE)

# %%
df.head(5)
# Out:
#      TRANSACTION_ID DATE_EMITTED   AMOUNT TYPE_OF_PAYMENT  \
# 0  31aa748f9e646175   2024-06-13  2187.72        Transfer
# 1  817cf6e66f3e5b23   2024-04-20     4.94    Direct Debit
# 2  f1075bdd028a7a57   2024-07-10     3.77        Transfer
# 3  720c8b280626c086   2023-10-22   130.87     Credit Card
# 4  ec9989e34acff854   2024-04-09  4582.19    Direct Debit
#
#             MERCHANT_NAME                                        DESCRIPTION  \
# 0              FACILECOMM               PRLV FACILECOMM SAS 2414822G10219163
# 1     GOOGLE CLOUD FRANCE  PRLV SEPA GOOGLE CLOUD FRANCE S GG103JLMOS CLO...
# 2                AMPEVINO                 LES VOUTES - FA00003482 - AMPEVINO
# 3                 LECLERC                                                NaN
# 4  LEODIS ACHAT BOISSONS                        EFFETS DOMICILIES DOMICILIES
#
#    SIDE                                          CATEGORY
# 0     0            Bank Fees & Charges: Subscription Fees
# 1     0             Technology Expenses: Hosting Services
# 2     0                          Food & Beverage Expenses
# 3     0  Operational Expenses: Other Operational Expenses
# 4     0                          Food & Beverage Expenses

# %%
df[['CATEGORY_LVL_1', 'CATEGORY_LVL_2']] = df['CATEGORY'].str.split(':', n=1, expand=True).apply(lambda x: x.str.strip())

# %%
df['DATE_EMITTED'] = pd.to_datetime(df['DATE_EMITTED'], errors='coerce')

# %%
df["DESCRIPTION_EMPTY"] = df["DESCRIPTION"].isna() | (df["DESCRIPTION"].str.strip() == "")
df["LOG_AMOUNT"] = np.log1p(df["AMOUNT"].abs())

# %%
colonne = "SIDE"
df[colonne].unique()
# Out:
# array([0])

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 337237 entries, 0 to 337236
# Data columns (total 12 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   TRANSACTION_ID     337237 non-null  str
#  1   DATE_EMITTED       337237 non-null  datetime64[us]
#  2   AMOUNT             337237 non-null  float64
#  3   TYPE_OF_PAYMENT    330812 non-null  str
#  4   MERCHANT_NAME      330884 non-null  str
#  5   DESCRIPTION        271875 non-null  str
#  6   SIDE               337237 non-null  int64
#  7   CATEGORY           337237 non-null  str
#  8   CATEGORY_LVL_1     337237 non-null  str
#  9   CATEGORY_LVL_2     291053 non-null  str
#  10  DESCRIPTION_EMPTY  337237 non-null  bool
#  11  LOG_AMOUNT         337237 non-null  float64
# dtypes: bool(1), datetime64[us](1), float64(2), int64(1), str(7)
# memory usage: 28.6 MB

# %%
print("=" * 60)
print("APERÇU GÉNÉRAL")
print("=" * 60)
print(f"Lignes          : {len(df):,}")
print(f"Colonnes        : {list(df.columns)}")
print(f"Période         : {df['DATE_EMITTED'].min().date()} → {df['DATE_EMITTED'].max().date()}")
print(f"Catégories      : {df['CATEGORY'].nunique()} unique(s)")
print(f"\nValeurs manquantes (%) :")
print((df.isnull().mean() * 100).round(2).to_string())
print()
# Out:
# ============================================================
# APERÇU GÉNÉRAL
# ============================================================
# Lignes          : 337,237
# Colonnes        : ['TRANSACTION_ID', 'DATE_EMITTED', 'AMOUNT', 'TYPE_OF_PAYMENT', 'MERCHANT_NAME', 'DESCRIPTION', 'SIDE', 'CATEGORY', 'CATEGORY_LVL_1', 'CATEGORY_LVL_2', 'DESCRIPTION_EMPTY', 'LOG_AMOUNT']
# Période         : 2023-09-01 → 2024-09-18
# Catégories      : 42 unique(s)
#
# Valeurs manquantes (%) :
# TRANSACTION_ID        0.00
# DATE_EMITTED          0.00
# AMOUNT                0.00
# TYPE_OF_PAYMENT       1.91
# MERCHANT_NAME         1.88
# DESCRIPTION          19.38
# SIDE                  0.00
# CATEGORY              0.00
# CATEGORY_LVL_1        0.00
# CATEGORY_LVL_2       13.69
# DESCRIPTION_EMPTY     0.00
# LOG_AMOUNT            0.00

# %%
cat_counts = df["CATEGORY"].value_counts()
fig, ax = plt.subplots(figsize=(10, 12))

bars = sns.barplot(
    x=cat_counts.values,
    y=cat_counts.index,
    palette="Blues_r",
    ax=ax,
)
for bar, count in zip(ax.patches, cat_counts.values):
    pct = count / len(df) * 100
    ax.text(bar.get_width() + len(df) * 0.002, bar.get_y() + bar.get_height() / 2,
            f"{pct:.1f}%", va="center", fontsize=9)

ax.set_title("Categories distribution", fontsize=13, fontweight="bold")
ax.set_xlabel("Number of transactions")
ax.xaxis.set_major_formatter(mticker.FuncFormatter(lambda x, _: f"{int(x):,}"))
# Out:
# /var/folders/nl/rn83r53s2blg82xqwl7b1yv40000gn/T/ipykernel_31405/361597673.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   bars = sns.barplot(

# %%
empty_rate = (
    df.groupby("CATEGORY")["DESCRIPTION_EMPTY"]
    .mean()
    .sort_values(ascending=False)
    * 100
)

fig, ax = plt.subplots(figsize=(10, 12))
sns.barplot(x=empty_rate.values, y=empty_rate.index, ax=ax)
ax.set_title("% empty description per category", fontsize=13, fontweight="bold")
ax.set_xlabel("% empty descriptions")
ax.legend()
# Out:
# /var/folders/nl/rn83r53s2blg82xqwl7b1yv40000gn/T/ipykernel_31405/1039474929.py:12: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax.legend()

# %%
fig, ax = plt.subplots(figsize=(12, 12))
order = df.groupby("CATEGORY")["AMOUNT"].median().sort_values(ascending=False).index

sns.boxplot(
    data=df,
    x="AMOUNT",
    y="CATEGORY",
    order=order,
    palette="coolwarm",
    flierprops=dict(marker=".", markersize=2, alpha=0.4),
    ax=ax,
)
ax.set_title("Distribution of transaction amount pet cateogry", fontsize=13, fontweight="bold")
ax.set_xlabel("Amount (€)")

p95 = df["AMOUNT"].quantile(0.95)
p05 = df["AMOUNT"].quantile(0.05)
ax.set_xlim(p05 * 1.5, p95 * 1.5)
# Out:
# /var/folders/nl/rn83r53s2blg82xqwl7b1yv40000gn/T/ipykernel_31405/949638925.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(
# (2.175, 15179.625000000004)

# %%
pivot = (
    df.groupby(["CATEGORY", "TYPE_OF_PAYMENT"])
    .size()
    .unstack(fill_value=0)
)
pivot_pct = pivot.div(pivot.sum(axis=1), axis=0) * 100

fig, ax = plt.subplots(figsize=(12, 10))
sns.heatmap(
    pivot_pct,
    annot=True,
    fmt=".0f",
    cmap="YlOrRd",
    linewidths=0.5,
    cbar_kws={"label": "% of transactions"},
    ax=ax,
)
ax.set_title("Paiment type × Category (% row)", fontsize=13, fontweight="bold")
ax.set_xlabel("Payment type")
# Out:
# Text(0.5, 80.7222222222222, 'Payment type')

# %%
side_pct_norm = (
    df.groupby(["CATEGORY", "SIDE"])
      .size()
      .unstack(fill_value=0)
      .rename(columns=lambda x: "Débit" if x == 0 else "Crédit")
      .pipe(lambda df: df.div(df.sum(axis=1), axis=0) * 100)
      .sort_values("Crédit" if "Crédit" in df["SIDE"].unique() else "Débit")
)

fig, ax = plt.subplots(figsize=(10, 12))
side_pct_norm.plot(
    kind="barh",
    stacked=True,
    ax=ax,
    width=0.7,
)
ax.axvline(50, color="black", linestyle="--", linewidth=0.8)
ax.set_title("Debit / Credit ratio per category", fontsize=13, fontweight="bold")
ax.set_xlabel("% of transactions")
ax.set_ylabel("")
ax.legend(loc="lower right")

# %%
# Pour chaque catégorie, % de transactions couvertes par le top-10 marchands
coverage = []
for cat, group in df.groupby("CATEGORY"):
    top10_count = group["MERCHANT_NAME"].value_counts().head(10).sum()
    coverage.append({"CATEGORY": cat, "TOP10_COVERAGE_PCT": top10_count / len(group) * 100})
coverage_df = pd.DataFrame(coverage).sort_values("TOP10_COVERAGE_PCT", ascending=True)

fig, ax = plt.subplots(figsize=(10, max(5, len(coverage_df) * 0.45)))
sns.barplot(x="TOP10_COVERAGE_PCT", y="CATEGORY", data=coverage_df, ax=ax)
ax.axvline(50, color="red", linestyle="--", linewidth=1.2, label="50% threshold")
ax.set_title("% of transactions covered by the top 10 merchants", fontsize=13, fontweight="bold")
ax.set_xlabel("Coverage by the top 10 (%)")
ax.set_ylabel("")
ax.legend()

# %%
num_features = df[["AMOUNT", "LOG_AMOUNT", "SIDE", "DESCRIPTION_EMPTY"]].copy()
num_features["PAYMENT_ENCODED"] = df["TYPE_OF_PAYMENT"].astype("category").cat.codes
num_features["DAY_OF_WEEK"] = df["DATE_EMITTED"].dt.dayofweek
num_features["MONTH_NUM"] = df["DATE_EMITTED"].dt.month

corr = num_features.corr()

fig, ax = plt.subplots(figsize=(8, 6))
mask = np.triu(np.ones_like(corr, dtype=bool))
sns.heatmap(
    corr,
    mask=mask,
    annot=True,
    fmt=".2f",
    cmap="RdBu_r",
    center=0,
    vmin=-1, vmax=1,
    linewidths=0.5,
    ax=ax,
)
ax.set_title("Correlation of numerical features", fontsize=13, fontweight="bold")
# Out:
# Text(0.5, 1.0, 'Correlation of numerical features')

# %%
nb_cat = 20

df["MONTH"] = df["DATE_EMITTED"].dt.to_period("M").astype(str)
monthly = df.groupby(["MONTH", "CATEGORY"]).size().unstack(fill_value=0)

top_x = cat_counts.head(nb_cat).index.tolist()
monthly_top_x = monthly[top_x]

fig, ax = plt.subplots(figsize=(14, 5))
monthly_top_x.plot(ax=ax, marker="o", markersize=3, linewidth=1.5)
ax.set_title(f"Monthly volumes — Top {nb_cat} categories", fontsize=13, fontweight="bold")
ax.set_xlabel("Month")
ax.set_ylabel("Nb transactions")
ax.tick_params(axis="x", rotation=45)
ax.legend(bbox_to_anchor=(1.01, 1), loc="upper left", fontsize=9)

# %%
DAYS_FR = ["Lundi", "Mardi", "Mercredi", "Jeudi", "Vendredi", "Samedi", "Dimanche"]

df["DAY_OF_WEEK"]  = df["DATE_EMITTED"].dt.dayofweek          # 0=Lundi … 6=Dimanche
df["DAY_OF_WEEK_LABEL"] = df["DAY_OF_WEEK"].map(dict(enumerate(DAYS_FR)))
df["DAY_OF_MONTH"] = df["DATE_EMITTED"].dt.day                 # 1 … 31
df["WEEK_PART"]    = df["DAY_OF_WEEK"].apply(                  # Semaine vs Week-end
    lambda d: "Week-end" if d >= 5 else "Semaine"
)
df["MONTH_THIRD"]  = pd.cut(                                   # Tiers du mois
    df["DAY_OF_MONTH"], bins=[0, 10, 20, 31],
    labels=["Début (1-10)", "Milieu (11-20)", "Fin (21-31)"]
)

# %%
TOP_N = 40
top_cats = df["CATEGORY"].value_counts().head(TOP_N).index.tolist()
df_top = df[df["CATEGORY"].isin(top_cats)]

# %%
pivot_dow = (
    df_top.groupby(["CATEGORY", "DAY_OF_WEEK_LABEL"])
    .size()
    .unstack(fill_value=0)
    .reindex(columns=DAYS_FR, fill_value=0)
)
# Normalisation par ligne pour comparer les profils, pas les volumes
pivot_dow_pct = pivot_dow.div(pivot_dow.sum(axis=1), axis=0) * 100

fig, ax = plt.subplots(figsize=(11, max(5, len(pivot_dow_pct) * 0.55)))
sns.heatmap(
    pivot_dow_pct,
    annot=True, fmt=".0f",
    cmap="YlOrRd",
    linewidths=0.5,
    cbar_kws={"label": "% des transactions de la catégorie"},
    ax=ax,
)
ax.set_title(f"Profil hebdomadaire par catégorie (% ligne) — Top {TOP_N}\n"
             "(→ une distribution uniforme ≈ 14%/jour = jour sans pouvoir discriminant)",
             fontsize=13, fontweight="bold")
ax.set_xlabel("")
ax.set_ylabel("")
# Out:
# Text(108.22222222222219, 0.5, '')

# %%
pivot_dom = (
    df_top.groupby(["CATEGORY", "MONTH_THIRD"])
    .size()
    .unstack(fill_value=0)
)
pivot_dom_pct = pivot_dom.div(pivot_dom.sum(axis=1), axis=0) * 100

fig, ax = plt.subplots(figsize=(9, max(5, len(pivot_dom_pct) * 0.55)))
sns.heatmap(
    pivot_dom_pct,
    annot=True, fmt=".0f",
    cmap="YlOrRd",
    linewidths=0.5,
    cbar_kws={"label": "% des transactions de la catégorie"},
    ax=ax,
)
ax.set_title(f"Profil mensuel par catégorie (% ligne, tiers du mois) — Top {TOP_N}\n"
             "(→ pic en début/fin de mois = signal fort pour loyers, salaires, abonnements)",
             fontsize=13, fontweight="bold")
ax.set_xlabel("")
ax.set_ylabel("")
# Out:
# Text(83.22222222222219, 0.5, '')
