# %%
import os
import sys

# 1. Configurer les chemins
REPO_URL = "https://github.com/ton-username/qonto-classifier.git"  # À adapter
PROJECT_NAME = "qonto-classifier"

# 2. Cloner le repo si on est sur Colab
if 'google.colab' in str(get_ipython()):
    if not os.path.exists(PROJECT_NAME):
        # !git clone {REPO_URL}
    # %cd {PROJECT_NAME}

# 3. Installer uv et synchroniser les dépendances
# !curl -LsSf https://astral.sh/uv/install.sh | sh
os.environ['PATH'] += ":/root/.cargo/bin"
# !uv sync

# 4. Ajouter 'src' au path pour importer tes fonctions de nettoyage
sys.path.append(os.path.abspath("src"))

print("🚀 Environnement Colab prêt !")
